# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
# Load dataset
creditcard_apps = pd.read_csv("CC_data.csv")
# Inspect data
creditcard_apps.head()
# Out:
#   Male    Age   Debt Married BankCustomer EducationLevel Ethnicity  \
# 0    b  30.83  0.000       u            g              w         v
# 1    a  58.67  4.460       u            g              q         h
# 2    a   24.5  0.500       u            g              q         h
# 3    b  27.83  1.540       u            g              w         v
# 4    b  20.17  5.625       u            g              w         v
#
#    YearsEmployed PriorDefault Employed  CreditScore DriversLicense Citizen  \
# 0           1.25            t        t            1              f       g
# 1           3.04            t        t            6              f       g
# 2           1.50            t        f            0              f       g
# 3           3.75            t        t            5              t       g
# 4           1.71            t        f            0              f       s
#
#   ZipCode  Income Approved
# 0     202       0        +
# 1      43     560        +
# ...

# %%
# Print summary statistics
cc_apps_description = creditcard_apps.describe()
print(cc_apps_description)

print("\n")

# Print DataFrame information
cc_apps_info =creditcard_apps.info()
print(cc_apps_info)

print("\n")

# Inspect missing values in the dataset
creditcard_apps.tail(n=17)
# Out:
#              Debt  YearsEmployed  CreditScore         Income
# count  690.000000     690.000000    690.00000     690.000000
# mean     4.758725       2.223406      2.40000    1017.385507
# std      4.978163       3.346513      4.86294    5210.102598
# min      0.000000       0.000000      0.00000       0.000000
# 25%      1.000000       0.165000      0.00000       0.000000
# 50%      2.750000       1.000000      0.00000       5.000000
# 75%      7.207500       2.625000      3.00000     395.500000
# max     28.000000      28.500000     67.00000  100000.000000
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 690 entries, 0 to 689
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Male            690 non-null    object
#  1   Age             690 non-null    object
#  2   Debt            690 non-null    float64
#  3   Married         690 non-null    object
# ...

# %%
# Inspect missing values in the dataset
print(creditcard_apps.tail())

# Replace the '?'s with NaN
creditcard_apps = creditcard_apps.replace('?',np.NaN)

# Inspect the missing values again
creditcard_apps.tail(n=17)
# Out:
#     Male    Age    Debt Married BankCustomer EducationLevel Ethnicity  \
# 685    b  21.08  10.085       y            p              e         h
# 686    a  22.67   0.750       u            g              c         v
# 687    a  25.25  13.500       y            p             ff        ff
# 688    b  17.92   0.205       u            g             aa         v
# 689    b     35   3.375       u            g              c         h
#
#      YearsEmployed PriorDefault Employed  CreditScore DriversLicense Citizen  \
# 685           1.25            f        f            0              f       g
# 686           2.00            f        t            2              t       g
# 687           2.00            f        t            1              t       g
# 688           0.04            f        f            0              f       g
# 689           8.29            f        f            0              t       g
#
#     ZipCode  Income Approved
# 685     260       0        -
# ...

# %%
def plotDistPlot(col):
    sns.distplot(col)
    plt.show()
plotDistPlot(creditcard_apps['CreditScore'])
plotDistPlot(creditcard_apps['Debt'])

# %%
#scatterplot
sns.set()
cols = ['Age', 'Income', 'CreditScore', 'Debt', 'YearsEmployed']
sns.pairplot(creditcard_apps[cols], size = 2.5)
plt.show();

# %%
# Impute the missing values with mean imputation
creditcard_apps.fillna(creditcard_apps.mean(), inplace=True)

# Count the number of NaNs in the dataset and print the counts to verify
print(creditcard_apps.isnull().sum())

# Iterate over each column of cc_apps
for col in creditcard_apps.columns:
    # Check if the column is of object type
    if creditcard_apps[col].dtypes == 'object':
        # Impute with the most frequent value
        creditcard_apps = creditcard_apps.fillna(creditcard_apps[col].value_counts().index[0])

# Count the number of NaNs in the dataset and print the counts to verify
print(creditcard_apps.isnull().sum())
# Out:
# Male              12
# Age               12
# Debt               0
# Married            6
# BankCustomer       6
# EducationLevel     9
# Ethnicity          9
# YearsEmployed      0
# PriorDefault       0
# Employed           0
# CreditScore        0
# DriversLicense     0
# Citizen            0
# ZipCode           13
# Income             0
# Approved           0
# dtype: int64
# Male              0
# Age               0
# Debt              0
# Married           0
# BankCustomer      0
# EducationLevel    0
# Ethnicity         0
# YearsEmployed     0
# PriorDefault      0
# Employed          0
# CreditScore       0
# DriversLicense    0
# Citizen           0
# ZipCode           0
# Income            0
# Approved          0
# dtype: int64

# %%
# Import LabelEncoder
from sklearn.preprocessing import LabelEncoder

# Instantiate LabelEncoder
le=LabelEncoder()

# Iterate over all the values of each column and extract their dtypes
for col in creditcard_apps.columns.to_numpy():
    # Compare if the dtype is object
    if creditcard_apps[col].dtypes=='object':
    # Use LabelEncoder to do the numeric transformation
        creditcard_apps[col]=le.fit_transform(creditcard_apps[col])

# %%
# Import train_test_split
from sklearn.model_selection import train_test_split

# Drop the features 11 and 13 and convert the DataFrame to a NumPy array
creditcard_apps =creditcard_apps.drop(['DriversLicense','ZipCode'], axis=1)
creditcard_apps = creditcard_apps.values

# Segregate features and labels into separate variables
X,y = creditcard_apps[:,0:13] , creditcard_apps[:,13]

# Split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X
                                                    ,
                                                    y,
                                                    test_size=0.33,
                                                    random_state=42)

# %%
# Import MinMaxScaler
from sklearn.preprocessing import MinMaxScaler

# Instantiate MinMaxScaler and use it to rescale X_train and X_test
scaler = MinMaxScaler(feature_range=(0, 1))
rescaledX_train = scaler.fit_transform(X_train)
rescaledX_test = scaler.transform(X_test)

# %%
# Import LogisticRegression
from sklearn.linear_model import LogisticRegression

# Instantiate a LogisticRegression classifier with default parameter values
logreg = LogisticRegression()

# Fit logreg to the train set
logreg.fit(rescaledX_train,y_train)
# Out:
# LogisticRegression()

# %%
# Import confusion_matrix
from sklearn.metrics import confusion_matrix

# Use logreg to predict instances from the test set and store it
y_pred = logreg.predict(rescaledX_test)

# Get the accuracy score of logreg model and print it
print("Accuracy of logistic regression classifier: ", logreg.score(rescaledX_test,y_test))

# Print the confusion matrix of the logreg model
confusion_matrix(y_test,y_pred)
# Out:
# Accuracy of logistic regression classifier:  0.8421052631578947
# array([[94,  9],
#        [27, 98]], dtype=int64)

# %%
# Import GridSearchCV
from sklearn.model_selection import GridSearchCV

# Define the grid of values for tol and max_iter
tol = [0.01, 0.001 ,0.0001]
max_iter = [100, 150, 200]

# Create a dictionary where tol and max_iter are keys and the lists of their values are the corresponding values
param_grid = dict(tol=tol, max_iter=max_iter)

# %%
# Instantiate GridSearchCV with the required parameters
grid_model = GridSearchCV(estimator=logreg, param_grid=param_grid, cv=5)

# Use scaler to rescale X and assign it to rescaledX
rescaledX = scaler.fit_transform(X)

# Fit grid_model to the data
grid_model_result = grid_model.fit(rescaledX, y)

# Summarize results
best_score, best_params = grid_model_result.best_score_, grid_model_result.best_params_
print("Best: %f using %s" % (best_score, best_params))
# Out:
# Best: 0.850725 using {'max_iter': 100, 'tol': 0.01}

# %%
rescaledX = scaler.transform(X)
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
rf = RandomForestClassifier(n_estimators=500)
rf.fit(rescaledX_train, y_train)
y_pred = rf.predict(rescaledX_test)
print("Random Forest classifier has accuracy of: ", rf.score(rescaledX_test, y_test))
# Evaluate the confusion_matrix
confusion_matrix(y_test, y_pred)
# Out:
# Random Forest classifier has accuracy of:  0.8596491228070176
# array([[ 87,  16],
#        [ 16, 109]], dtype=int64)
